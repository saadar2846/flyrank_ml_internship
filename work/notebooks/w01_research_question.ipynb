# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saadar2846/flyrank_ml_internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, subprocess

REPO_URL = "https://github.com/saadar2846/flyrank_ml_internship"
REPO_DIR = "flyrank_ml_internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)
print(os.getcwd())
print(os.listdir())
# Out:
# /content/flyrank_ml_internship
# ['notebooks', 'data', '02_your_first_readable_model.ipynb', 'requirements.txt', 'README.md', 'skills', '.gitignore', 'scripts', 'CLAUDE.md', 'DATA_USE.md', '.git', 'submission', 'work', 'AGENTS.md', 'outputs', '.github', 'LICENSE', 'docs', 'SETUP.md', 'GUIDE.md']

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Ranking Signal Analysis
#
# I'm picking this lane because Week 1 already surfaced a concrete signal question worth digging into:
# does `avg_position` relate to `ctr` as strongly as intuition suggests? The answer (r = -0.073) was
# much weaker than expected, which tells me there's real work in separating which observable signals
# actually matter for visibility/clicks/engagement versus which ones are commonly assumed to matter but
# don't hold up under a real check. This lane lets me build a signal report the content team can trust
# before acting on it, rather than relying on assumptions like "position always drives clicks."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# /content
# ['.config', 'sample_data']

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision this improves: which signals a content strategist should weight when deciding what to
# fix on underperforming pages — right now that's mostly intuition (e.g. "older pages need refreshing,"
# "better position always means better CTR").
#
# **Who acts on it:** a content strategist or SEO reviewer, using the signal report to reprioritize
# their content checklist.
#
# **Action taken:** spending less editorial time chasing signals that show weak/no real relationship
# (like assuming position alone drives CTR) and more time on signals with a real, measurable association.
#
# **Cost of a wrong recommendation:** if I report a signal as meaningful when it's actually noise, the
# team wastes limited editorial time optimizing something that won't move the metric. If I under-report
# a real signal, they miss a lever that would have worked. Because this is observational, not
# experimental, data, the deeper risk is mistaking a correlation for a cause — recommending an action
# based on "these two things move together" when something else drives both.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Three real numbers from the starter dataset that motivate this lane:

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd, numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1: the "obvious" signal barely holds up on its own
corr = df[['avg_position', 'ctr']].corr().iloc[0, 1]
print(f"avg_position vs ctr correlation: {corr:.3f}")

# Number 2: a learned model finds structure a fixed rule misses (verified from outputs/model_results.json)
print("Baseline rule Precision@50: 0.240  |  Random forest Precision@50: 0.740")

# Number 3: how many pages have enough volume to trust a CTR/position reading at all
n_total = len(df)
n_meaningful = (df['impressions_90d'] >= 500).sum()
print(f"Pages with impressions_90d >= 500: {n_meaningful} of {n_total} ({n_meaningful/n_total:.1%})")
# Out:
# avg_position vs ctr correlation: -0.073
# Baseline rule Precision@50: 0.240  |  Random forest Precision@50: 0.740
# Pages with impressions_90d >= 500: 16726 of 30000 (55.8%)

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can say:** observed, directional associations between signals and outcomes in this
# 30,000-row anonymized starter slice (and later, the warehouse release) — e.g. "pages with X tend to
# have higher/lower Y in this data," framed as decision support for a human reviewer.
#
# **What I will never say:**
# - That any signal *causes* a change in ranking or clicks — this is observational data, not an experiment.
# - That any result reflects a Google algorithm factor.
# - That a weak correlation today rules out a real effect in a narrower slice (e.g. only top-10
#   positions) — averaging across all positions can hide a steeper effect near the top.
# - Anything tied to a specific client, domain, or URL — outputs stay aggregated and pseudonymized.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
